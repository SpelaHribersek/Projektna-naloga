# %% [markdown]
# # ANALIZA PODATKOV

# %%
import pandas as pd

nagrajenci = pd.read_csv("nagrajenci.csv")

# %%
nagrajenci.head(10)
# Out:
#    leto podrocje                  ime  \
# 0  1901   Fizika      Wilhelm Röntgen
# 1  1902   Fizika      Hendrik Lorentz
# 2  1902   Fizika        Pieter Zeeman
# 3  1903   Fizika      Henri Becquerel
# 4  1903   Fizika         Pierre Curie
# 5  1903   Fizika          Marie Curie
# 6  1904   Fizika        Lord Rayleigh
# 7  1905   Fizika       Philipp Lenard
# 8  1906   Fizika        J. J. Thomson
# 9  1907   Fizika  Albert A. Michelson
#
#                                                  URL poklic datum rojstva  \
# 0  https://en.wikipedia.org/wiki/Wilhelm_R%C3%B6n...    NaN    1845-03-27
# 1      https://en.wikipedia.org/wiki/Hendrik_Lorentz    NaN    1853-07-18
# 2        https://en.wikipedia.org/wiki/Pieter_Zeeman    NaN    1865-05-25
# 3      https://en.wikipedia.org/wiki/Henri_Becquerel    NaN    1852-12-15
# 4         https://en.wikipedia.org/wiki/Pierre_Curie    NaN    1859-05-15
# 5          https://en.wikipedia.org/wiki/Marie_Curie    NaN    1867-11-07
# ...

# %%
nagrajenci.tail(10)
# Out:
#       leto   podrocje                ime  \
# 1018  2021  Ekonomija         David Card
# 1019  2021  Ekonomija     Joshua Angrist
# 1020  2021  Ekonomija       Guido Imbens
# 1021  2022  Ekonomija       Ben Bernanke
# 1022  2022  Ekonomija    Douglas Diamond
# 1023  2022  Ekonomija   Philip H. Dybvig
# 1024  2023  Ekonomija     Claudia Goldin
# 1025  2024  Ekonomija     Daron Acemoglu
# 1026  2024  Ekonomija      Simon Johnson
# 1027  2024  Ekonomija  James A. Robinson
#
#                                                   URL poklic datum rojstva  \
# 1018         https://en.wikipedia.org/wiki/David_Card    NaN          1956
# 1019     https://en.wikipedia.org/wiki/Joshua_Angrist    NaN    1960-09-18
# 1020       https://en.wikipedia.org/wiki/Guido_Imbens    NaN    1963-09-03
# 1021       https://en.wikipedia.org/wiki/Ben_Bernanke    NaN    1953-12-13
# 1022    https://en.wikipedia.org/wiki/Douglas_Diamond    NaN    1953-10-25
# ...
